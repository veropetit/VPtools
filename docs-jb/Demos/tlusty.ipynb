# %% [markdown]
# # Using TLUSTY synthetic spectra

# %%
import specpolFlow as pol
import numpy as np
import matplotlib.pyplot as plt

import VPtools as vp

# %%
path = "/Users/vpetit/ASTRO/ReferenceMaterial/TLUSTY/OSTAR2002/Gvispec"

wl, flux, cont = vp.synth.read_tlusty(path+'/G27500g300v10.vis')

spec = vp.synth.read_tlusty_norm(path+'/G27500g300v10.vis')

# %%
fig, ax = plt.subplots(1,1)

ax.plot(wl, flux)
ax.plot(wl, cont)

fig, ax = plt.subplots(1,1)

ax.plot(spec.wl, spec.specI)

# %%
delta = wl[1:] - wl[:-1]

fig, ax = plt.subplots(1,1)
ax.plot(delta)
